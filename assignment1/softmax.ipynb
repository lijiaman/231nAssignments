# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
  """
  Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
  it for the linear classifier. These are the same steps as we used for the
  SVM, but condensed to a single function.  
  """
  # Load the raw CIFAR-10 data
  cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
  X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
  
  # subsample the data
  mask = range(num_training, num_training + num_validation)
  X_val = X_train[mask]
  y_val = y_train[mask]
  mask = range(num_training)
  X_train = X_train[mask]
  y_train = y_train[mask]
  mask = range(num_test)
  X_test = X_test[mask]
  y_test = y_test[mask]
  mask = np.random.choice(num_training, num_dev, replace=False)
  X_dev = X_train[mask]
  y_dev = y_train[mask]
  
  # Preprocessing: reshape the image data into rows
  X_train = np.reshape(X_train, (X_train.shape[0], -1))
  X_val = np.reshape(X_val, (X_val.shape[0], -1))
  X_test = np.reshape(X_test, (X_test.shape[0], -1))
  X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
  
  # Normalize the data: subtract the mean image
  mean_image = np.mean(X_train, axis = 0)
  X_train -= mean_image
  X_val -= mean_image
  X_test -= mean_image
  X_dev -= mean_image
  
  # add bias dimension and transform into columns
  X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
  X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
  X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
  X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
  
  return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print 'Train data shape: ', X_train.shape
print 'Train labels shape: ', y_train.shape
print 'Validation data shape: ', X_val.shape
print 'Validation labels shape: ', y_val.shape
print 'Test data shape: ', X_test.shape
print 'Test labels shape: ', y_test.shape
print 'dev data shape: ', X_dev.shape
print 'dev labels shape: ', y_dev.shape
# Out:
# Train data shape:  (49000L, 3073L)
# Train labels shape:  (49000L,)
# Validation data shape:  (1000L, 3073L)
# Validation labels shape:  (1000L,)
# Test data shape:  (1000L, 3073L)
# Test labels shape:  (1000L,)
# dev data shape:  (500L, 3073L)
# dev labels shape:  (500L,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print 'loss: %f' % loss
print 'sanity check: %f' % (-np.log(0.1))
# Out:
# loss: 2.332324
# sanity check: 2.302585

# %% [markdown]
# ## Inline Question 1:
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# **Your answer:** *Fill this in*

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 1e2)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 1e2)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: -1.725007 analytic: -1.725007, relative error: 1.583635e-08
# numerical: -1.759323 analytic: -1.759324, relative error: 3.127003e-08
# numerical: -0.439655 analytic: -0.439655, relative error: 9.019180e-08
# numerical: -0.348399 analytic: -0.348399, relative error: 1.582472e-07
# numerical: 0.445875 analytic: 0.445875, relative error: 5.235730e-08
# numerical: 0.340379 analytic: 0.340379, relative error: 3.037935e-08
# numerical: 0.892015 analytic: 0.892015, relative error: 8.630410e-09
# numerical: -0.215635 analytic: -0.215635, relative error: 2.213516e-08
# numerical: 3.544469 analytic: 3.544469, relative error: 5.060405e-09
# numerical: -2.337724 analytic: -2.337724, relative error: 4.938047e-09
# numerical: 4.077871 analytic: 4.077871, relative error: 5.593582e-09
# numerical: -1.734245 analytic: -1.734245, relative error: 2.832452e-08
# numerical: 0.425117 analytic: 0.425117, relative error: 5.866880e-09
# numerical: -1.068660 analytic: -1.068660, relative error: 4.399034e-08
# numerical: 0.139409 analytic: 0.139408, relative error: 4.572510e-07
# numerical: 4.198059 analytic: 4.198059, relative error: 1.806034e-09
# numerical: -0.936697 analytic: -0.936697, relative error: 9.929800e-09
# numerical: 2.498446 analytic: 2.498446, relative error: 1.054788e-08
# numerical: 3.094598 analytic: 3.094598, relative error: 1.740283e-08
# numerical: 1.555142 analytic: 1.555142, relative error: 4.514608e-09

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.00001)
toc = time.time()
print 'naive loss: %e computed in %fs' % (loss_naive, toc - tic)

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.00001)
toc = time.time()
print 'vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic)

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print 'Loss difference: %f' % np.abs(loss_naive - loss_vectorized)
print 'Gradient difference: %f' % grad_difference
# Out:
# naive loss: 2.332324e+00 computed in 0.350000s
# vectorized loss: 2.332324e+00 computed in 0.016000s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
learning_rates = [1e-7, 5e-7]
regularization_strengths = [1e4, 2e4, 3e4, 4e4, 5e4, 6e4, 7e4, 8e4, 9e4, 1e8]

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################
num_iters = 1500
for rate in learning_rates:
  for reg in regularization_strengths:
    soft = Softmax()
    soft_loss_hist = soft.train(X_train, y_train, rate, reg, num_iters, verbose=True)
    y_train_pred = soft.predict(X_train)
    y_train_acc = np.mean(y_train_pred == y_train)
    y_val_pred = soft.predict(X_val)
    y_val_acc = np.mean(y_val_pred == y_val)
    results[(rate, reg)] = (y_train_acc, y_val_acc)
    if y_val_acc > best_val:
        best_val = y_val_acc
        best_softmax = soft
    

pass
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print 'lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy)
    
print 'best validation accuracy achieved during cross-validation: %f' % best_val
# Out:
# iteration 0 / 1500: loss 158.565452
# iteration 100 / 1500: loss 128.255246
# iteration 200 / 1500: loss 104.737604
# iteration 300 / 1500: loss 85.971421
# iteration 400 / 1500: loss 70.523979
# iteration 500 / 1500: loss 58.137694
# iteration 600 / 1500: loss 47.701618
# iteration 700 / 1500: loss 39.360720
# iteration 800 / 1500: loss 32.511122
# iteration 900 / 1500: loss 26.943764
# iteration 1000 / 1500: loss 22.364006
# iteration 1100 / 1500: loss 18.610400
# iteration 1200 / 1500: loss 15.568506
# iteration 1300 / 1500: loss 13.161755
# iteration 1400 / 1500: loss 10.983951
# iteration 0 / 1500: loss 313.537804
# iteration 100 / 1500: loss 209.095637
# iteration 200 / 1500: loss 140.422898
# iteration 300 / 1500: loss 94.289694
# iteration 400 / 1500: loss 63.702594
# iteration 500 / 1500: loss 43.381949
# iteration 600 / 1500: loss 29.662783
# iteration 700 / 1500: loss 20.462494
# iteration 800 / 1500: loss 14.421063
# iteration 900 / 1500: loss 10.296323
# iteration 1000 / 1500: loss 7.529051
# iteration 1100 / 1500: loss 5.677205
# iteration 1200 / 1500: loss 4.504557
# iteration 1300 / 1500: loss 3.669538
# iteration 1400 / 1500: loss 3.091405
# iteration 0 / 1500: loss 462.554284
# iteration 100 / 1500: loss 253.513010
# iteration 200 / 1500: loss 139.651536
# iteration 300 / 1500: loss 77.320319
# iteration 400 / 1500: loss 43.145674
# iteration 500 / 1500: loss 24.507691
# iteration 600 / 1500: loss 14.337136
# iteration 700 / 1500: loss 8.774980
# iteration 800 / 1500: loss 5.693616
# iteration 900 / 1500: loss 4.062017
# iteration 1000 / 1500: loss 3.153746
# iteration 1100 / 1500: loss 2.647476
# iteration 1200 / 1500: loss 2.502615
# iteration 1300 / 1500: loss 2.200562
# iteration 1400 / 1500: loss 2.118972
# iteration 0 / 1500: loss 627.322745
# iteration 100 / 1500: loss 281.245755
# iteration 200 / 1500: loss 126.966572
# iteration 300 / 1500: loss 57.991998
# iteration 400 / 1500: loss 27.024658
# iteration 500 / 1500: loss 13.257764
# iteration 600 / 1500: loss 7.035226
# iteration 700 / 1500: loss 4.276200
# iteration 800 / 1500: loss 3.051210
# iteration 900 / 1500: loss 2.518561
# iteration 1000 / 1500: loss 2.230077
# iteration 1100 / 1500: loss 2.183410
# iteration 1200 / 1500: loss 2.108792
# iteration 1300 / 1500: loss 2.071225
# iteration 1400 / 1500: loss 2.136805
# iteration 0 / 1500: loss 774.373268
# iteration 100 / 1500: loss 284.019316
# iteration 200 / 1500: loss 105.178414
# iteration 300 / 1500: loss 39.778826
# iteration 400 / 1500: loss 15.896673
# iteration 500 / 1500: loss 7.180642
# iteration 600 / 1500: loss 3.915009
# iteration 700 / 1500: loss 2.746365
# iteration 800 / 1500: loss 2.358358
# iteration 900 / 1500: loss 2.205678
# iteration 1000 / 1500: loss 2.085176
# iteration 1100 / 1500: loss 2.147480
# iteration 1200 / 1500: loss 2.124799
# iteration 1300 / 1500: loss 2.103443
# iteration 1400 / 1500: loss 2.141902
# iteration 0 / 1500: loss 918.644455
# iteration 100 / 1500: loss 276.073679
# iteration 200 / 1500: loss 83.970396
# iteration 300 / 1500: loss 26.664473
# iteration 400 / 1500: loss 9.403628
# iteration 500 / 1500: loss 4.312100
# iteration 600 / 1500: loss 2.724027
# iteration 700 / 1500: loss 2.295760
# iteration 800 / 1500: loss 2.145454
# iteration 900 / 1500: loss 2.117046
# iteration 1000 / 1500: loss 2.074560
# iteration 1100 / 1500: loss 2.111277
# iteration 1200 / 1500: loss 2.090952
# iteration 1300 / 1500: loss 2.080022
# iteration 1400 / 1500: loss 2.067163
# iteration 0 / 1500: loss 1080.853533
# iteration 100 / 1500: loss 265.743737
# iteration 200 / 1500: loss 66.595775
# iteration 300 / 1500: loss 17.889743
# iteration 400 / 1500: loss 5.980845
# iteration 500 / 1500: loss 3.067065
# iteration 600 / 1500: loss 2.309206
# iteration 700 / 1500: loss 2.163358
# iteration 800 / 1500: loss 2.131025
# iteration 900 / 1500: loss 2.141553
# iteration 1000 / 1500: loss 2.046669
# iteration 1100 / 1500: loss 2.159775
# iteration 1200 / 1500: loss 2.141265
# iteration 1300 / 1500: loss 2.056360
# iteration 1400 / 1500: loss 2.106748
# iteration 0 / 1500: loss 1223.054294
# iteration 100 / 1500: loss 246.091551
# iteration 200 / 1500: loss 50.911880
# iteration 300 / 1500: loss 11.828712
# iteration 400 / 1500: loss 4.073265
# iteration 500 / 1500: loss 2.504915
# iteration 600 / 1500: loss 2.188672
# iteration 700 / 1500: loss 2.171914
# iteration 800 / 1500: loss 2.122686
# iteration 900 / 1500: loss 2.181588
# iteration 1000 / 1500: loss 2.088276
# iteration 1100 / 1500: loss 2.131585
# iteration 1200 / 1500: loss 2.069140
# iteration 1300 / 1500: loss 2.112683
# iteration 1400 / 1500: loss 2.100955
# iteration 0 / 1500: loss 1376.474406
# iteration 100 / 1500: loss 226.426785
# iteration 200 / 1500: loss 38.827739
# iteration 300 / 1500: loss 8.114120
# iteration 400 / 1500: loss 3.108830
# iteration 500 / 1500: loss 2.287559
# iteration 600 / 1500: loss 2.133937
# iteration 700 / 1500: loss 2.174060
# iteration 800 / 1500: loss 2.118910
# iteration 900 / 1500: loss 2.126377
# iteration 1000 / 1500: loss 2.101812
# iteration 1100 / 1500: loss 2.143344
# iteration 1200 / 1500: loss 2.152049
# iteration 1300 / 1500: loss 2.076988
# iteration 1400 / 1500: loss 2.099927
# iteration 0 / 1500: loss 1531614.422843
# iteration 100 / 1500: loss inf
# iteration 200 / 1500: loss inf
# iteration 300 / 1500: loss inf
# iteration 400 / 1500: loss nan
# iteration 500 / 1500: loss nan
# iteration 600 / 1500: loss nan
# iteration 700 / 1500: loss nan
# iteration 800 / 1500: loss nan
# iteration 900 / 1500: loss nan
# iteration 1000 / 1500: loss nan
# iteration 1100 / 1500: loss nan
# iteration 1200 / 1500: loss nan
# iteration 1300 / 1500: loss nan
# iteration 1400 / 1500: loss nan
# iteration 0 / 1500: loss 160.458501
# iteration 100 / 1500: loss 58.785027
# iteration 200 / 1500: loss 22.645167
# iteration 300 / 1500: loss 9.463027
# iteration 400 / 1500: loss 4.760676
# iteration 500 / 1500: loss 2.915589
# iteration 600 / 1500: loss 2.423487
# iteration 700 / 1500: loss 2.026889
# iteration 800 / 1500: loss 2.042101
# iteration 900 / 1500: loss 1.855644
# iteration 1000 / 1500: loss 1.953414
# iteration 1100 / 1500: loss 1.998847
# iteration 1200 / 1500: loss 1.891768
# iteration 1300 / 1500: loss 1.924736
# iteration 1400 / 1500: loss 1.912675
# iteration 0 / 1500: loss 314.708919
# iteration 100 / 1500: loss 43.205165
# iteration 200 / 1500: loss 7.475355
# iteration 300 / 1500: loss 2.649322
# iteration 400 / 1500: loss 2.125599
# iteration 500 / 1500: loss 2.013908
# iteration 600 / 1500: loss 2.015447
# iteration 700 / 1500: loss 2.071779
# iteration 800 / 1500: loss 1.962970
# iteration 900 / 1500: loss 1.940852
# iteration 1000 / 1500: loss 1.992147
# iteration 1100 / 1500: loss 1.933507
# iteration 1200 / 1500: loss 1.991260
# iteration 1300 / 1500: loss 1.952979
# iteration 1400 / 1500: loss 1.995611
# iteration 0 / 1500: loss 463.550624
# iteration 100 / 1500: loss 24.169317
# iteration 200 / 1500: loss 3.165405
# iteration 300 / 1500: loss 2.103742
# iteration 400 / 1500: loss 2.057232
# iteration 500 / 1500: loss 2.079537
# iteration 600 / 1500: loss 2.040203
# iteration 700 / 1500: loss 2.143846
# iteration 800 / 1500: loss 1.962572
# iteration 900 / 1500: loss 2.102742
# iteration 1000 / 1500: loss 2.016708
# iteration 1100 / 1500: loss 2.058914
# iteration 1200 / 1500: loss 2.042477
# iteration 1300 / 1500: loss 2.062177
# iteration 1400 / 1500: loss 2.072057
# iteration 0 / 1500: loss 617.459033
# iteration 100 / 1500: loss 12.730127
# iteration 200 / 1500: loss 2.267538
# iteration 300 / 1500: loss 2.050572
# iteration 400 / 1500: loss 2.021111
# iteration 500 / 1500: loss 2.121003
# iteration 600 / 1500: loss 2.101287
# iteration 700 / 1500: loss 2.045051
# iteration 800 / 1500: loss 2.076409
# iteration 900 / 1500: loss 2.052684
# iteration 1000 / 1500: loss 2.098143
# iteration 1100 / 1500: loss 2.099183
# iteration 1200 / 1500: loss 2.059884
# iteration 1300 / 1500: loss 2.109711
# iteration 1400 / 1500: loss 2.053110
# iteration 0 / 1500: loss 772.381100
# iteration 100 / 1500: loss 6.822078
# iteration 200 / 1500: loss 2.160315
# iteration 300 / 1500: loss 2.068380
# iteration 400 / 1500: loss 2.105054
# iteration 500 / 1500: loss 2.067630
# iteration 600 / 1500: loss 2.116114
# iteration 700 / 1500: loss 2.108907
# iteration 800 / 1500: loss 2.094250
# iteration 900 / 1500: loss 2.054187
# iteration 1000 / 1500: loss 2.132952
# iteration 1100 / 1500: loss 2.097880
# iteration 1200 / 1500: loss 2.052064
# iteration 1300 / 1500: loss 2.145577
# iteration 1400 / 1500: loss 2.121133
# iteration 0 / 1500: loss 932.609514
# iteration 100 / 1500: loss 4.108796
# iteration 200 / 1500: loss 2.118075
# iteration 300 / 1500: loss 2.089014
# iteration 400 / 1500: loss 2.132757
# iteration 500 / 1500: loss 2.094114
# iteration 600 / 1500: loss 2.069479
# iteration 700 / 1500: loss 2.167316
# iteration 800 / 1500: loss 2.035176
# iteration 900 / 1500: loss 2.128601
# iteration 1000 / 1500: loss 2.151875
# iteration 1100 / 1500: loss 2.095192
# iteration 1200 / 1500: loss 2.097192
# iteration 1300 / 1500: loss 2.141878
# iteration 1400 / 1500: loss 2.086147
# iteration 0 / 1500: loss 1080.566512
# iteration 100 / 1500: loss 2.998924
# iteration 200 / 1500: loss 2.143274
# iteration 300 / 1500: loss 2.125407
# iteration 400 / 1500: loss 2.113810
# iteration 500 / 1500: loss 2.137546
# iteration 600 / 1500: loss 2.111548
# iteration 700 / 1500: loss 2.178274
# iteration 800 / 1500: loss 2.158477
# iteration 900 / 1500: loss 2.092909
# iteration 1000 / 1500: loss 2.112308
# iteration 1100 / 1500: loss 2.085804
# iteration 1200 / 1500: loss 2.151300
# iteration 1300 / 1500: loss 2.098737
# iteration 1400 / 1500: loss 2.120061
# iteration 0 / 1500: loss 1244.088051
# iteration 100 / 1500: loss 2.497869
# iteration 200 / 1500: loss 2.187296
# iteration 300 / 1500: loss 2.145908
# iteration 400 / 1500: loss 2.077151
# iteration 500 / 1500: loss 2.196512
# iteration 600 / 1500: loss 2.122634
# iteration 700 / 1500: loss 2.078505
# iteration 800 / 1500: loss 2.114233
# iteration 900 / 1500: loss 2.102790
# iteration 1000 / 1500: loss 2.128706
# iteration 1100 / 1500: loss 2.171150
# iteration 1200 / 1500: loss 2.104417
# iteration 1300 / 1500: loss 2.101938
# iteration 1400 / 1500: loss 2.139941
# iteration 0 / 1500: loss 1374.126063
# iteration 100 / 1500: loss 2.304490
# iteration 200 / 1500: loss 2.065446
# iteration 300 / 1500: loss 2.129182
# iteration 400 / 1500: loss 2.085368
# iteration 500 / 1500: loss 2.128048
# iteration 600 / 1500: loss 2.141027
# iteration 700 / 1500: loss 2.085167
# iteration 800 / 1500: loss 2.146700
# iteration 900 / 1500: loss 2.107888
# iteration 1000 / 1500: loss 2.168319
# iteration 1100 / 1500: loss 2.165104
# iteration 1200 / 1500: loss 2.146877
# iteration 1300 / 1500: loss 2.139746
# iteration 1400 / 1500: loss 2.205138
# iteration 0 / 1500: loss 1557909.850366
# iteration 100 / 1500: loss inf
# iteration 200 / 1500: loss nan
# iteration 300 / 1500: loss nan
# iteration 400 / 1500: loss nan
# iteration 500 / 1500: loss nan
# iteration 600 / 1500: loss nan
# iteration 700 / 1500: loss nan
# iteration 800 / 1500: loss nan
# iteration 900 / 1500: loss nan
# iteration 1000 / 1500: loss nan
# iteration 1100 / 1500: loss nan
# iteration 1200 / 1500: loss nan
# iteration 1300 / 1500: loss nan
# iteration 1400 / 1500: loss nan
# lr 1.000000e-07 reg 1.000000e+04 train accuracy: 0.335122 val accuracy: 0.344000
# lr 1.000000e-07 reg 2.000000e+04 train accuracy: 0.350306 val accuracy: 0.366000
# lr 1.000000e-07 reg 3.000000e+04 train accuracy: 0.340857 val accuracy: 0.357000
# lr 1.000000e-07 reg 4.000000e+04 train accuracy: 0.334776 val accuracy: 0.346000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.330796 val accuracy: 0.341000
# lr 1.000000e-07 reg 6.000000e+04 train accuracy: 0.322245 val accuracy: 0.339000
# lr 1.000000e-07 reg 7.000000e+04 train accuracy: 0.317061 val accuracy: 0.329000
# lr 1.000000e-07 reg 8.000000e+04 train accuracy: 0.313510 val accuracy: 0.322000
# lr 1.000000e-07 reg 9.000000e+04 train accuracy: 0.313755 val accuracy: 0.324000
# lr 1.000000e-07 reg 1.000000e+08 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-07 reg 1.000000e+04 train accuracy: 0.374102 val accuracy: 0.391000
# lr 5.000000e-07 reg 2.000000e+04 train accuracy: 0.348102 val accuracy: 0.358000
# lr 5.000000e-07 reg 3.000000e+04 train accuracy: 0.345898 val accuracy: 0.359000
# lr 5.000000e-07 reg 4.000000e+04 train accuracy: 0.334878 val accuracy: 0.344000
# lr 5.000000e-07 reg 5.000000e+04 train accuracy: 0.320939 val accuracy: 0.343000
# lr 5.000000e-07 reg 6.000000e+04 train accuracy: 0.309347 val accuracy: 0.330000
# lr 5.000000e-07 reg 7.000000e+04 train accuracy: 0.308306 val accuracy: 0.324000
# lr 5.000000e-07 reg 8.000000e+04 train accuracy: 0.309980 val accuracy: 0.326000
# lr 5.000000e-07 reg 9.000000e+04 train accuracy: 0.310408 val accuracy: 0.321000
# lr 5.000000e-07 reg 1.000000e+08 train accuracy: 0.100265 val accuracy: 0.087000
# best validation accuracy achieved during cross-validation: 0.391000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print 'softmax on raw pixels final test set accuracy: %f' % (test_accuracy, )
# Out:
# softmax on raw pixels final test set accuracy: 0.366000

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in xrange(10):
  plt.subplot(2, 5, i + 1)
  
  # Rescale the weights to be between 0 and 255
  wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
  plt.imshow(wimg.astype('uint8'))
  plt.axis('off')
  plt.title(classes[i])
